# %%
#|default_exp accel

# %% [markdown]
# # Denoising Diffusion Probabilistic Models with miniai

# %% [markdown]
# ## Imports

# %%
#|export
import pickle,gzip,math,os,time,shutil,torch,random,logging
import fastcore.all as fc,matplotlib as mpl,numpy as np,matplotlib.pyplot as plt
from collections.abc import Mapping
from pathlib import Path
from functools import partial
from types import SimpleNamespace

from fastcore.foundation import L
from fastprogress import progress_bar
import torchvision.transforms.functional as TF, torch.nn.functional as F
from torch import tensor,nn,optim
from torch.utils.data import DataLoader,default_collate
from torch.nn import init
from torch.optim import lr_scheduler

from miniai.datasets import *
from miniai.conv import *
from miniai.learner import *
from miniai.activations import *
from miniai.init import *
from miniai.sgd import *
from miniai.resnet import *
from miniai.augment import *

# %%
set_seed(42)

# %%
mpl.rcParams['image.cmap'] = 'gray_r'
logging.disable(logging.WARNING)

# %% [markdown]
# ## Load the dataset

# %%
config = SimpleNamespace(    
    epochs = 100,
    model_name="ddpm_clouds",
    noise_steps=1000,
    seed = 42,
    batch_size = 64,
    img_size = 64,
    device = "cuda",
    use_wandb = True,
    num_workers=8,
    num_frames=3,
    lr = 5e-4)

# %%
def ls(path): 
    return sorted(list(path.iterdir()))

# %%
import torchvision.transforms as T

class CloudDataset:
    
    def __init__(self, files, num_frames=4, scale=True, size=64):
        
        self.tfms = T.Compose([T.Resize((size, int(size*1.7))), 
                               T.RandomCrop(size),
                               T.RandomHorizontalFlip(),])
        
        data = []
        for file in progress_bar(files, leave=False):
            one_day = np.load(file)
            if scale:
                one_day = 0.5 - self._scale(one_day)
        
            wds = np.lib.stride_tricks.sliding_window_view(
                one_day.squeeze(), 
                num_frames, 
                axis=0).transpose((0,3,1,2))
            data.append(wds)
        self.data = np.concatenate(data, axis=0)
            
    @staticmethod
    def _scale(arr):
        "Scales values of array in [0,1]"
        m, M = arr.min(), arr.max()
        return (arr - m) / (M - m)
    
    def __getitem__(self, idx):
        return self.tfms(torch.from_numpy(self.data[idx]))
    
    def __len__(self): return len(self.data)

    def save(self, fname="cloud_frames.npy"):
        np.save(fname, self.data)

# %%
import wandb
with wandb.init(project="ddpm_clouds"):
    artifact = wandb.use_artifact('capecape/gtc/np_dataset:v0', type='dataset')
    artifact_dir = artifact.download()
# Out:
# Tracking run with wandb version 0.13.9
# Run data is saved locally in <code>/home/tcapelle/wandb/torch_moving_mnist/nbs/wandb/run-20230118_230637-fowbvc8s</code>
# Syncing run <strong><a href="https://wandb.ai/capecape/ddpm_clouds/runs/fowbvc8s" target="_blank">zany-dawn-15</a></strong> to <a href="https://wandb.ai/capecape/ddpm_clouds" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#  View project at <a href="https://wandb.ai/capecape/ddpm_clouds" target="_blank">https://wandb.ai/capecape/ddpm_clouds</a>
#  View run at <a href="https://wandb.ai/capecape/ddpm_clouds/runs/fowbvc8s" target="_blank">https://wandb.ai/capecape/ddpm_clouds/runs/fowbvc8s</a>
# wandb: Downloading large artifact np_dataset:v0, 3816.62MB. 30 files...
# wandb:   30 of 30 files downloaded.
# Done. 0:0:0.0
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
#  View run <strong style="color:#cdcd00">zany-dawn-15</strong> at: <a href="https://wandb.ai/capecape/ddpm_clouds/runs/fowbvc8s" target="_blank">https://wandb.ai/capecape/ddpm_clouds/runs/fowbvc8s</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230118_230637-fowbvc8s/logs</code>

# %%
files = ls(Path(artifact_dir))

# %%
train_ds = CloudDataset(files[0:-3])
valid_ds = CloudDataset(files[-3:])
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
idxs = torch.randperm(len(valid_ds))

# %%
valid_ds.data = valid_ds.data[idxs]

# %%
train_dl = DataLoader(train_ds, config.batch_size, shuffle=True, num_workers=config.num_workers)
valid_dl = DataLoader(valid_ds, config.batch_size, num_workers=config.num_workers)

# %%
dls = DataLoaders(train_dl, valid_dl)

# %%
dt = dls.train
xb = next(iter(dt))
xb.shape
# Out:
# torch.Size([64, 4, 64, 64])

# %%
show_images(xb[:4].reshape(-1, 1, config.img_size, config.img_size), imsize=1.5, nrows=4)

# %%
betamin,betamax,n_steps = 0.0001,0.02,config.noise_steps
beta = torch.linspace(betamin, betamax, n_steps)
alpha = 1.-beta
alphabar = alpha.cumprod(dim=0)
sigma = beta.sqrt()

# %%
def noisify(x0, ᾱ):
    "Noise only the last frame"
    past_frames = x0[:,:-1]
    x0 = x0[:,-1:]
    device = x0.device
    n = len(x0)
    t = torch.randint(0, n_steps, (n,), dtype=torch.long)
    ε = torch.randn(x0.shape, device=device)
    ᾱ_t = ᾱ[t].reshape(-1, 1, 1, 1).to(device)
    xt = ᾱ_t.sqrt()*x0 + (1-ᾱ_t).sqrt()*ε
    return torch.cat([past_frames, xt], dim=1), t.to(device), ε

# %%
xt, t, ε = noisify(xb[:4],alphabar)
t
# Out:
# tensor([166, 134, 507, 793])

# %%
xt.shape
# Out:
# torch.Size([4, 4, 64, 64])

# %%
titles = fc.map_ex(t, '{}')
titles = fc.concat(zip([[None,None,None]]*len(titles), titles)) 
show_images(xt.reshape(-1, 1, config.img_size, config.img_size), imsize=1.5, titles=titles, nrows=4)

# %% [markdown]
# ## Training

# %%
from diffusers import UNet2DModel

# %%
def init_ddpm(model):
    for o in model.down_blocks:
        for p in o.resnets:
            p.conv2.weight.data.zero_()
            for p in fc.L(o.downsamplers): init.orthogonal_(p.conv.weight)

    for o in model.up_blocks:
        for p in o.resnets: p.conv2.weight.data.zero_()

    model.conv_out.weight.data.zero_()

# %%
def collate_ddpm(b): return noisify(default_collate(b), alphabar)

# %%
def dl_ddpm(ds, shuffle=False): return DataLoader(ds, batch_size=config.batch_size, collate_fn=collate_ddpm, shuffle=shuffle, num_workers=config.num_workers)

# %%
dls = DataLoaders(dl_ddpm(train_ds, shuffle=True), dl_ddpm(valid_ds))

# %%
@torch.no_grad()
def sample(model, xt):
    ps = next(model.parameters())
    past_frames = xt[:,:-1]
    x_t = torch.randn_like(xt[:,-1:], dtype=xt.dtype)
    preds = []
    for t in progress_bar(reversed(range(n_steps)), total=n_steps, leave=False):
        t_batch = torch.full((x_t.shape[0],), t, device=ps.device, dtype=torch.long)
        z = (torch.randn(x_t.shape) if t > 0 else torch.zeros(x_t.shape)).to(ps)
        ᾱ_t1 = alphabar[t-1]  if t > 0 else torch.tensor(1)
        b̄_t = 1-alphabar[t]
        b̄_t1 = 1-ᾱ_t1
        noise = model(torch.cat([past_frames, x_t], dim=1), t_batch).sample
        x_0_hat = ((x_t - b̄_t.sqrt() * noise)/alphabar[t].sqrt())
        x_t = x_0_hat * ᾱ_t1.sqrt()*(1-alpha[t])/b̄_t + x_t * alpha[t].sqrt()*b̄_t1/b̄_t + sigma[t]*z
        preds.append(x_t.float().cpu())
    return preds

# %% [markdown]
# ## Accelerate

# %% [markdown]
# `pip install accelerate` before running this section.

# %%
from accelerate import Accelerator

# %%
class AccelerateCB(TrainCB):
    order = DeviceCB.order+10
    def __init__(self, n_inp=1, mixed_precision="fp16"):
        super().__init__(n_inp=n_inp)
        self.acc = Accelerator(mixed_precision=mixed_precision)
        
    def before_fit(self, learn):
        learn.model,learn.opt,learn.dls.train,learn.dls.valid = self.acc.prepare(
            learn.model, learn.opt, learn.dls.train, learn.dls.valid)
    
    def after_fit(self, learn):
        learn.model = self.acc.unwrap_model(learn.model)
    
    def backward(self, learn): self.acc.backward(learn.loss)

# %%
import wandb
class WandbCB(Callback):
    "Hacky W&B callback"
    order = MetricsCB.order+1
    def __init__(self, model_name=None): self.model_name = model_name
    def before_fit(self, learn):
        if wandb.run is None:
            raise Exception("You have to run fit inside a wandb run")
        if hasattr(learn, 'metrics'): 
            self._log_copy = learn.metrics._log
            learn.metrics._log = self._log
        self.losses = []

    def _log(self, d):
        self._log_copy(d)
        wandb.log(d)
    
    def after_batch(self, learn):
        if learn.training:
            wandb.log({"train_loss":learn.loss.item(),
                       "lr":learn.schedo.get_last_lr()[0]})
    def after_fit(self, learn):
        if self.model_name is not None:
            model_name = f"{wandb.run.id}_{self.model_name}"
            at = wandb.Artifact(model_name, type="model")
            torch.save(learn.model.state_dict(), f"models/{self.model_name}.pth")
            at.add_file(f"models/{self.model_name}.pth")
            wandb.log_artifact(at)

# %%
def to_wandb_image(img):
    return wandb.Image(torch.cat(img.split(1), dim=-1).cpu().numpy())

def log_images(model, xt):
    samples = sample(model, xt)
    frames = torch.cat([xt[:, :-1,...].to(samples[-1].device), samples[-1]], dim=1)
    wandb.log({"sampled_images": [to_wandb_image(img) for img in frames]})

# %%
class LogPreds(Callback):
    "Log samples to W&B"
    order = 99
    def __init__(self, n_preds=10, log_every=1): 
        self.n_preds=n_preds
        self.log_every = log_every
    
    def before_fit(self, learn):
        dt = learn.dls.valid
        xt, t, ε = next(iter(dt))
        self.xt = xt[:self.n_preds]
    
    def after_epoch(self, learn):
        if not learn.training and ((learn.epoch+1) % self.log_every == 0):
            log_images(learn.model, self.xt)

# %%
class DDPMCB2(Callback):
    def after_predict(self, learn): learn.preds = learn.preds.sample

# %%
tmax = config.epochs * len(dls.train)
sched = partial(lr_scheduler.OneCycleLR, max_lr=config.lr, total_steps=tmax)
opt_func = partial(optim.Adam, eps=1e-5)

# %%
model = UNet2DModel(in_channels=4, out_channels=1, block_out_channels=(32, 64, 128, 256), norm_num_groups=8)
init_ddpm(model)
cbs = [DDPMCB2(), ProgressCB(plot=True), MetricsCB(), BatchSchedCB(sched), AccelerateCB(n_inp=2)]
learn = Learner(model, dls, nn.MSELoss(), lr=config.lr, cbs=cbs, opt_func=opt_func)

# %%
{cb.__class__.__name__:cb.order for cb in learn.cbs}
# Out:
# {'DDPMCB2': 0,
#  'ProgressCB': 1,
#  'MetricsCB': 0,
#  'BatchSchedCB': 0,
#  'AccelerateCB': 10}

# %%
run = wandb.init(project="ddpm_clouds", config=config)

learn.fit(config.epochs, cbs=[WandbCB("ddpm_clouds"), LogPreds(log_every=10)])
# Out:
# Tracking run with wandb version 0.13.9
# Run data is saved locally in <code>/home/tcapelle/wandb/torch_moving_mnist/nbs/wandb/run-20230118_230710-xq6vlibx</code>
# Syncing run <strong><a href="https://wandb.ai/capecape/ddpm_clouds/runs/xq6vlibx" target="_blank">vital-jazz-16</a></strong> to <a href="https://wandb.ai/capecape/ddpm_clouds" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#  View project at <a href="https://wandb.ai/capecape/ddpm_clouds" target="_blank">https://wandb.ai/capecape/ddpm_clouds</a>
#  View run at <a href="https://wandb.ai/capecape/ddpm_clouds/runs/xq6vlibx" target="_blank">https://wandb.ai/capecape/ddpm_clouds/runs/xq6vlibx</a>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='97' class='' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       97.00% [97/100 36:01&lt;01:06]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.975</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.938</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.894</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.845</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.788</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.728</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.659</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.587</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.512</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.434</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.362</td>
#       <td>5</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.290</td>
#       <td>5</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.229</td>
#       <td>6</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.174</td>
#       <td>6</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.125</td>
#       <td>7</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.088</td>
#       <td>7</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.059</td>
#       <td>8</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.044</td>
#       <td>8</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.025</td>
#       <td>9</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.020</td>
#       <td>9</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.012</td>
#       <td>10</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.018</td>
#       <td>10</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.009</td>
#       <td>11</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.007</td>
#       <td>11</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.008</td>
#       <td>12</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.010</td>
#       <td>12</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.008</td>
#       <td>13</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.008</td>
#       <td>13</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.008</td>
#       <td>14</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.010</td>
#       <td>14</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>15</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.008</td>
#       <td>15</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.007</td>
#       <td>16</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.009</td>
#       <td>16</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.006</td>
#       <td>17</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.008</td>
#       <td>17</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>18</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.010</td>
#       <td>18</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.007</td>
#       <td>19</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.008</td>
#       <td>19</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>20</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>20</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.008</td>
#       <td>21</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.014</td>
#       <td>21</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>22</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.006</td>
#       <td>22</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>23</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.009</td>
#       <td>23</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.006</td>
#       <td>24</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.009</td>
#       <td>24</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>25</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.008</td>
#       <td>25</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>26</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.006</td>
#       <td>26</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.006</td>
#       <td>27</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>27</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.006</td>
#       <td>28</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.012</td>
#       <td>28</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.004</td>
#       <td>29</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.007</td>
#       <td>29</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>30</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.014</td>
#       <td>30</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.008</td>
#       <td>31</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.008</td>
#       <td>31</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.007</td>
#       <td>32</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.007</td>
#       <td>32</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.006</td>
#       <td>33</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.010</td>
#       <td>33</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.004</td>
#       <td>34</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.008</td>
#       <td>34</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.006</td>
#       <td>35</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.007</td>
#       <td>35</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.004</td>
#       <td>36</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.010</td>
#       <td>36</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>37</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.006</td>
#       <td>37</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.003</td>
#       <td>38</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.006</td>
#       <td>38</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>39</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.006</td>
#       <td>39</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>40</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>40</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>41</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.006</td>
#       <td>41</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>42</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.009</td>
#       <td>42</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>43</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.011</td>
#       <td>43</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.004</td>
#       <td>44</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.007</td>
#       <td>44</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.006</td>
#       <td>45</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.013</td>
#       <td>45</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>46</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.013</td>
#       <td>46</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>47</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.006</td>
#       <td>47</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>48</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.009</td>
#       <td>48</td>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
wandb.finish()

# %%
# !sudo poweroff

# %% [markdown]
# ## Generate Longer sequences...

# %% [markdown]
# The idea is use the same model in an autorgressive way so we can generate arbitrary long sequences.

# %% [markdown]
# Let's load the trained model

# %%
import torch
from diffusers import UNet2DModel

from fastprogress import progress_bar

# %%
@torch.no_grad()
def sample(model, xt):
    ps = next(model.parameters())
    xt = xt.to(ps.device)
    past_frames = xt[:,:-1]
    x_t = torch.randn_like(xt[:,-1:], dtype=xt.dtype)
    preds = []
    for t in progress_bar(reversed(range(n_steps)), total=n_steps, leave=False):
        t_batch = torch.full((x_t.shape[0],), t, device=ps.device, dtype=torch.long)
        z = (torch.randn(x_t.shape) if t > 0 else torch.zeros(x_t.shape)).to(ps)
        ᾱ_t1 = alphabar[t-1]  if t > 0 else torch.tensor(1)
        b̄_t = 1-alphabar[t]
        b̄_t1 = 1-ᾱ_t1
        noise = model(torch.cat([past_frames, x_t], dim=1), t_batch).sample
        x_0_hat = ((x_t - b̄_t.sqrt() * noise)/alphabar[t].sqrt())
        x_t = x_0_hat * ᾱ_t1.sqrt()*(1-alpha[t])/b̄_t + x_t * alpha[t].sqrt()*b̄_t1/b̄_t + sigma[t]*z
    return x_t.float()

# %%
ds = torch.load("mmnist_01_40x40.pt") - 0.5
# ds = ds[0:3000]

# %%
model = UNet2DModel(in_channels=4, out_channels=1, block_out_channels=(16, 32, 64, 128), norm_num_groups=8)

# %%
model.load_state_dict(torch.load("models/test_model.pth"))
model.eval();

# %%
num_samples = 10
num_preds = 5

# %%
xt = ds[:num_samples].squeeze().cuda()
xt.shape
# Out:
# torch.Size([10, 4, 40, 40])

# %%
preds = []

for i in progress_bar(range(num_preds), total=num_preds):
    pred = sample(model.to(config.device), xt.cuda())
    preds.append(pred)
    xt = torch.cat([xt[:, 1:], pred], dim=1)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='5' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [5/5 02:24&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
preds[0].shape
# Out:
# torch.Size([10, 1, 40, 40])

# %%
past = ds[:num_samples].squeeze()

future = torch.cat(preds, dim=1).cpu()
past.shape, past.device, future.shape, future.device
# Out:
# (torch.Size([10, 4, 40, 40]),
#  device(type='cpu'),
#  torch.Size([10, 5, 40, 40]),
#  device(type='cpu'))

# %%
frames = torch.cat([past, future], dim=1).reshape(-1, 1, config.img_size, config.img_size)

# %%
show_images(frames, nrows=10, imsize=1.2)
