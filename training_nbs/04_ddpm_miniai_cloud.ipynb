# %% [markdown]
# # Denoising Diffusion Probabilistic Models with miniai

# %% [markdown]
# ## Imports

# %%
#|export
import pickle,gzip,math,os,time,shutil,torch,random,logging
import fastcore.all as fc,matplotlib as mpl,numpy as np,matplotlib.pyplot as plt
from collections.abc import Mapping
from pathlib import Path
from functools import partial
from types import SimpleNamespace

from fastcore.foundation import L
from fastprogress import progress_bar
import torchvision.transforms.functional as TF, torch.nn.functional as F
from torch import tensor,nn,optim
from torch.utils.data import DataLoader,default_collate
from torch.nn import init
from torch.optim import lr_scheduler

from miniai.datasets import *
from miniai.conv import *
from miniai.learner import *
from miniai.activations import *
from miniai.init import *
from miniai.sgd import *
from miniai.resnet import *
from miniai.augment import *

# %%
set_seed(42)

# %%
mpl.rcParams['image.cmap'] = 'gray_r'
logging.disable(logging.WARNING)

# %% [markdown]
# ## Load the dataset

# %%
config = SimpleNamespace(    
    epochs = 100,
    model_name="ddpm_clouds",
    noise_steps=1000,
    seed = 42,
    batch_size = 6,
    img_size = 128,
    device = "cuda",
    use_wandb = True,
    num_workers=8,
    num_frames=3,
    compile=True,
    lr = 5e-4)

# %%
def ls(path): 
    return sorted(list(path.iterdir()))

# %%
import torchvision.transforms as T

class CloudDataset:
    
    def __init__(self, files, num_frames=4, scale=True, size=64):
        
        self.tfms = T.Compose([T.Resize((size, int(size*1.7))), 
                               T.RandomCrop(size),
                               T.RandomHorizontalFlip(),])
        
        data = []
        for file in progress_bar(files, leave=False):
            one_day = np.load(file)
            if scale:
                one_day = 0.5 - self._scale(one_day)
        
            wds = np.lib.stride_tricks.sliding_window_view(
                one_day.squeeze(), 
                num_frames, 
                axis=0).transpose((0,3,1,2))
            data.append(wds)
        self.data = np.concatenate(data, axis=0)
            
    @staticmethod
    def _scale(arr):
        "Scales values of array in [0,1]"
        m, M = arr.min(), arr.max()
        return (arr - m) / (M - m)
    
    def __getitem__(self, idx):
        return self.tfms(torch.from_numpy(self.data[idx]))
    
    def __len__(self): return len(self.data)

    def save(self, fname="cloud_frames.npy"):
        np.save(fname, self.data)

# %%
import wandb
with wandb.init(project="ddpm_clouds"):
    artifact = wandb.use_artifact('capecape/gtc/np_dataset:v1', type='dataset')
    artifact_dir = artifact.download()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: capecape. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.13.9
# Run data is saved locally in <code>/home/tcapelle/wandb/torch_moving_mnist/training_nbs/wandb/run-20230127_012311-pobcjl90</code>
# Syncing run <strong><a href="https://wandb.ai/capecape/ddpm_clouds/runs/pobcjl90" target="_blank">beaming-rat-68</a></strong> to <a href="https://wandb.ai/capecape/ddpm_clouds" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#  View project at <a href="https://wandb.ai/capecape/ddpm_clouds" target="_blank">https://wandb.ai/capecape/ddpm_clouds</a>
#  View run at <a href="https://wandb.ai/capecape/ddpm_clouds/runs/pobcjl90" target="_blank">https://wandb.ai/capecape/ddpm_clouds/runs/pobcjl90</a>
# wandb: Downloading large artifact np_dataset:v1, 7633.24MB. 60 files...
# wandb:   60 of 60 files downloaded.
# Done. 0:0:0.0
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
#  View run <strong style="color:#cdcd00">beaming-rat-68</strong> at: <a href="https://wandb.ai/capecape/ddpm_clouds/runs/pobcjl90" target="_blank">https://wandb.ai/capecape/ddpm_clouds/runs/pobcjl90</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230127_012311-pobcjl90/logs</code>

# %%
# files = [f for f in ls(Path(artifact_dir)) if f.name.startswith("IR")]
files = ls(Path(artifact_dir))
files
# Out:
# [Path('artifacts/np_dataset:v1/B07_2022_06_01.npy'),
#  Path('artifacts/np_dataset:v1/B07_2022_06_02.npy'),
#  Path('artifacts/np_dataset:v1/B07_2022_06_03.npy'),
#  Path('artifacts/np_dataset:v1/B07_2022_06_04.npy'),
#  Path('artifacts/np_dataset:v1/B07_2022_06_05.npy'),
#  Path('artifacts/np_dataset:v1/B07_2022_06_06.npy'),
#  Path('artifacts/np_dataset:v1/B07_2022_06_07.npy'),
#  Path('artifacts/np_dataset:v1/B07_2022_06_08.npy'),
#  Path('artifacts/np_dataset:v1/B07_2022_06_09.npy'),
#  Path('artifacts/np_dataset:v1/B07_2022_06_10.npy'),
#  Path('artifacts/np_dataset:v1/B07_2022_06_11.npy'),
#  Path('artifacts/np_dataset:v1/B07_2022_06_12.npy'),
#  Path('artifacts/np_dataset:v1/B07_2022_06_13.npy'),
#  Path('artifacts/np_dataset:v1/B07_2022_06_14.npy'),
#  Path('artifacts/np_dataset:v1/B07_2022_06_15.npy'),
#  Path('artifacts/np_dataset:v1/B07_2022_06_16.npy'),
#  Path('artifacts/np_dataset:v1/B07_2022_06_17.npy'),
#  Path('artifacts/np_dataset:v1/B07_2022_06_18.npy'),
#  Path('artifacts/np_dataset:v1/B07_2022_06_19.npy'),
#  Path('artifacts/np_dataset:v1/B07_2022_06_20.npy'),
#  Path('artifacts/np_dataset:v1/B07_2022_06_21.npy'),
#  Path('artifacts/np_dataset:v1/B07_2022_06_22.npy'),
#  Path('artifacts/np_dataset:v1/B07_2022_06_23.npy'),
#  Path('artifacts/np_dataset:v1/B07_2022_06_24.npy'),
#  Path('artifacts/np_dataset:v1/B07_2022_06_25.npy'),
#  Path('artifacts/np_dataset:v1/B07_2022_06_26.npy'),
#  Path('artifacts/np_dataset:v1/B07_2022_06_27.npy'),
#  Path('artifacts/np_dataset:v1/B07_2022_06_28.npy'),
#  Path('artifacts/np_dataset:v1/B07_2022_06_29.npy'),
#  Path('artifacts/np_dataset:v1/B07_2022_06_30.npy'),
#  Path('artifacts/np_dataset:v1/IR108_2022_06_01.npy'),
#  Path('artifacts/np_dataset:v1/IR108_2022_06_02.npy'),
#  Path('artifacts/np_dataset:v1/IR108_2022_06_03.npy'),
#  Path('artifacts/np_dataset:v1/IR108_2022_06_04.npy'),
#  Path('artifacts/np_dataset:v1/IR108_2022_06_05.npy'),
#  Path('artifacts/np_dataset:v1/IR108_2022_06_06.npy'),
#  Path('artifacts/np_dataset:v1/IR108_2022_06_07.npy'),
#  Path('artifacts/np_dataset:v1/IR108_2022_06_08.npy'),
#  Path('artifacts/np_dataset:v1/IR108_2022_06_09.npy'),
#  Path('artifacts/np_dataset:v1/IR108_2022_06_10.npy'),
#  Path('artifacts/np_dataset:v1/IR108_2022_06_11.npy'),
#  Path('artifacts/np_dataset:v1/IR108_2022_06_12.npy'),
#  Path('artifacts/np_dataset:v1/IR108_2022_06_13.npy'),
#  Path('artifacts/np_dataset:v1/IR108_2022_06_14.npy'),
#  Path('artifacts/np_dataset:v1/IR108_2022_06_15.npy'),
#  Path('artifacts/np_dataset:v1/IR108_2022_06_16.npy'),
#  Path('artifacts/np_dataset:v1/IR108_2022_06_17.npy'),
#  Path('artifacts/np_dataset:v1/IR108_2022_06_18.npy'),
#  Path('artifacts/np_dataset:v1/IR108_2022_06_19.npy'),
#  Path('artifacts/np_dataset:v1/IR108_2022_06_20.npy'),
#  Path('artifacts/np_dataset:v1/IR108_2022_06_21.npy'),
#  Path('artifacts/np_dataset:v1/IR108_2022_06_22.npy'),
#  Path('artifacts/np_dataset:v1/IR108_2022_06_23.npy'),
#  Path('artifacts/np_dataset:v1/IR108_2022_06_24.npy'),
#  Path('artifacts/np_dataset:v1/IR108_2022_06_25.npy'),
#  Path('artifacts/np_dataset:v1/IR108_2022_06_26.npy'),
#  Path('artifacts/np_dataset:v1/IR108_2022_06_27.npy'),
#  Path('artifacts/np_dataset:v1/IR108_2022_06_28.npy'),
#  Path('artifacts/np_dataset:v1/IR108_2022_06_29.npy'),
#  Path('artifacts/np_dataset:v1/IR108_2022_06_30.npy')]

# %%
train_ds = CloudDataset(files[0:-3], size=config.img_size)
valid_ds = CloudDataset(files[-3:], size=config.img_size)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
idxs = torch.randperm(len(valid_ds))

# %%
valid_ds.data = valid_ds.data[idxs]

# %%
train_dl = DataLoader(train_ds, config.batch_size, shuffle=True, num_workers=config.num_workers)
valid_dl = DataLoader(valid_ds, config.batch_size, num_workers=config.num_workers)

# %%
dls = DataLoaders(train_dl, valid_dl)

# %%
dt = dls.train
xb = next(iter(dt))
xb.shape

show_images(xb[:4].reshape(-1, 1, config.img_size, config.img_size), imsize=1.5, nrows=4)

# %%
betamin,betamax,n_steps = 0.0001,0.02,config.noise_steps
beta = torch.linspace(betamin, betamax, n_steps)
alpha = 1.-beta
alphabar = alpha.cumprod(dim=0)
sigma = beta.sqrt()

# %%
def noisify(x0, ᾱ):
    "Noise only the last frame"
    past_frames = x0[:,:-1]
    x0 = x0[:,-1:]
    device = x0.device
    n = len(x0)
    t = torch.randint(0, n_steps, (n,), dtype=torch.long)
    ε = torch.randn(x0.shape, device=device)
    ᾱ_t = ᾱ[t].reshape(-1, 1, 1, 1).to(device)
    xt = ᾱ_t.sqrt()*x0 + (1-ᾱ_t).sqrt()*ε
    return torch.cat([past_frames, xt], dim=1), t.to(device), ε

# %%
xt, t, ε = noisify(xb[:4],alphabar)
t
# Out:
# tensor([619, 733,  70,  49])

# %%
xt.shape
# Out:
# torch.Size([4, 4, 128, 128])

# %%
titles = fc.map_ex(t, '{}')
titles = fc.concat(zip([[None,None,None]]*len(titles), titles)) 
show_images(xt.reshape(-1, 1, config.img_size, config.img_size), imsize=1.5, titles=titles, nrows=4)

# %% [markdown]
# ## Training

# %%
from diffusers import UNet2DModel

# %%
def init_ddpm(model):
    for o in model.down_blocks:
        for p in o.resnets:
            p.conv2.weight.data.zero_()
            for p in fc.L(o.downsamplers): init.orthogonal_(p.conv.weight)

    for o in model.up_blocks:
        for p in o.resnets: p.conv2.weight.data.zero_()

    model.conv_out.weight.data.zero_()

# %%
def collate_ddpm(b): return noisify(default_collate(b), alphabar)

# %%
def dl_ddpm(ds, shuffle=False): return DataLoader(ds, batch_size=config.batch_size, collate_fn=collate_ddpm, shuffle=shuffle, num_workers=config.num_workers)

# %%
dls = DataLoaders(dl_ddpm(train_ds, shuffle=True), dl_ddpm(valid_ds))

# %%
@torch.no_grad()
def sample(model, xt):
    ps = next(model.parameters())
    past_frames = xt[:,:-1]
    x_t = torch.randn_like(xt[:,-1:], dtype=xt.dtype)
    preds = []
    for t in progress_bar(reversed(range(n_steps)), total=n_steps, leave=False):
        t_batch = torch.full((x_t.shape[0],), t, device=ps.device, dtype=torch.long)
        z = (torch.randn(x_t.shape) if t > 0 else torch.zeros(x_t.shape)).to(ps)
        ᾱ_t1 = alphabar[t-1]  if t > 0 else torch.tensor(1)
        b̄_t = 1-alphabar[t]
        b̄_t1 = 1-ᾱ_t1
        noise = model(torch.cat([past_frames, x_t], dim=1), t_batch).sample
        x_0_hat = ((x_t - b̄_t.sqrt() * noise)/alphabar[t].sqrt())
        x_t = x_0_hat * ᾱ_t1.sqrt()*(1-alpha[t])/b̄_t + x_t * alpha[t].sqrt()*b̄_t1/b̄_t + sigma[t]*z
        preds.append(x_t.float().cpu())
    return preds

# %% [markdown]
# ## Accelerate

# %% [markdown]
# `pip install accelerate` before running this section.

# %%
from accelerate import Accelerator

# %%
class AccelerateCB(TrainCB):
    order = DeviceCB.order+10
    def __init__(self, n_inp=1, mixed_precision="fp16"):
        super().__init__(n_inp=n_inp)
        self.acc = Accelerator(mixed_precision=mixed_precision)
        
    def before_fit(self, learn):
        learn.model,learn.opt,learn.dls.train,learn.dls.valid = self.acc.prepare(
            learn.model, learn.opt, learn.dls.train, learn.dls.valid)
    
    def after_fit(self, learn):
        learn.model = self.acc.unwrap_model(learn.model)
    
    def backward(self, learn): self.acc.backward(learn.loss)

# %%
import wandb
class WandbCB(Callback):
    "Hacky W&B callback"
    order = MetricsCB.order+1
    def __init__(self, model_name=None): self.model_name = model_name
    def before_fit(self, learn):
        if wandb.run is None:
            raise Exception("You have to run fit inside a wandb run")
        if hasattr(learn, 'metrics'): 
            self._log_copy = learn.metrics._log
            learn.metrics._log = self._log
        self.losses = []

    def _log(self, d):
        self._log_copy(d)
        wandb.log(d)
    
    def after_batch(self, learn):
        if learn.training:
            wandb.log({"train_loss":learn.loss.item(),
                       "lr":learn.schedo.get_last_lr()[0]})
    def after_fit(self, learn):
        if self.model_name is not None:
            model_name = f"{wandb.run.id}_{self.model_name}"
            at = wandb.Artifact(model_name, type="model")
            torch.save(learn.model.state_dict(), f"models/{self.model_name}.pth")
            at.add_file(f"models/{self.model_name}.pth")
            wandb.log_artifact(at)

# %%
def to_wandb_image(img):
    return wandb.Image(torch.cat(img.split(1), dim=-1).cpu().numpy())

def log_images(model, xt):
    samples = sample(model, xt)
    frames = torch.cat([xt[:, :-1,...].to(samples[-1].device), samples[-1]], dim=1)
    wandb.log({"sampled_images": [to_wandb_image(img) for img in frames]})

# %%
class LogPreds(Callback):
    "Log samples to W&B"
    order = 99
    def __init__(self, n_preds=10, log_every=1): 
        self.n_preds=n_preds
        self.log_every = log_every
    
    def before_fit(self, learn):
        dt = learn.dls.valid
        xt, t, ε = next(iter(dt))
        self.xt = xt[:self.n_preds]
    
    def after_epoch(self, learn):
        if not learn.training and ((learn.epoch+1) % self.log_every == 0):
            log_images(learn.model, self.xt)

# %%
class DDPMCB2(Callback):
    def after_predict(self, learn): learn.preds = learn.preds.sample

# %%
tmax = config.epochs * len(dls.train)
sched = partial(lr_scheduler.OneCycleLR, max_lr=config.lr, total_steps=tmax)
opt_func = partial(optim.Adam, eps=1e-5)

# %%
model = UNet2DModel(in_channels=4, out_channels=1, block_out_channels=(32, 64, 128, 256), norm_num_groups=8)
init_ddpm(model)

# %%
cbs = [DDPMCB2(), ProgressCB(plot=True), MetricsCB(), BatchSchedCB(sched), AccelerateCB(n_inp=2)]
learn = Learner(model, dls, nn.MSELoss(), lr=config.lr, cbs=cbs, opt_func=opt_func)

# %%
{cb.__class__.__name__:cb.order for cb in learn.cbs}
# Out:
# {'DDPMCB2': 0,
#  'ProgressCB': 1,
#  'MetricsCB': 0,
#  'BatchSchedCB': 0,
#  'AccelerateCB': 10}

# %%
run = wandb.init(project="ddpm_clouds", config=config, tags=["big"])

learn.fit(config.epochs, cbs=[WandbCB("ddpm_clouds"), LogPreds(log_every=10)])
# Out:
# Tracking run with wandb version 0.13.9
# Run data is saved locally in <code>/home/tcapelle/wandb/torch_moving_mnist/training_nbs/wandb/run-20230127_012404-zdggd0q5</code>
# Syncing run <strong><a href="https://wandb.ai/capecape/ddpm_clouds/runs/zdggd0q5" target="_blank">brilliant-noodles-69</a></strong> to <a href="https://wandb.ai/capecape/ddpm_clouds" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#  View project at <a href="https://wandb.ai/capecape/ddpm_clouds" target="_blank">https://wandb.ai/capecape/ddpm_clouds</a>
#  View run at <a href="https://wandb.ai/capecape/ddpm_clouds/runs/zdggd0q5" target="_blank">https://wandb.ai/capecape/ddpm_clouds/runs/zdggd0q5</a>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.382</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.061</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.021</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.016</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.007</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.010</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.006</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.010</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.006</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.010</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>5</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.006</td>
#       <td>5</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.006</td>
#       <td>6</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>6</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.006</td>
#       <td>7</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.008</td>
#       <td>7</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.006</td>
#       <td>8</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.007</td>
#       <td>8</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>9</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.007</td>
#       <td>9</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>10</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.006</td>
#       <td>10</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>11</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.011</td>
#       <td>11</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>12</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.006</td>
#       <td>12</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>13</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.006</td>
#       <td>13</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.004</td>
#       <td>14</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>14</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.004</td>
#       <td>15</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>15</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.004</td>
#       <td>16</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.006</td>
#       <td>16</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.004</td>
#       <td>17</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.006</td>
#       <td>17</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.004</td>
#       <td>18</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.006</td>
#       <td>18</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.004</td>
#       <td>19</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.007</td>
#       <td>19</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.004</td>
#       <td>20</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.006</td>
#       <td>20</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.004</td>
#       <td>21</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.006</td>
#       <td>21</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.004</td>
#       <td>22</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.006</td>
#       <td>22</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.004</td>
#       <td>23</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.004</td>
#       <td>23</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.004</td>
#       <td>24</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.006</td>
#       <td>24</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.004</td>
#       <td>25</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>25</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.004</td>
#       <td>26</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>26</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.004</td>
#       <td>27</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>27</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.004</td>
#       <td>28</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>28</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.004</td>
#       <td>29</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>29</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.003</td>
#       <td>30</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.004</td>
#       <td>30</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.003</td>
#       <td>31</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>31</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.004</td>
#       <td>32</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.004</td>
#       <td>32</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.004</td>
#       <td>33</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.004</td>
#       <td>33</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.003</td>
#       <td>34</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.003</td>
#       <td>34</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.003</td>
#       <td>35</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>35</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.003</td>
#       <td>36</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.006</td>
#       <td>36</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.003</td>
#       <td>37</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.004</td>
#       <td>37</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.004</td>
#       <td>38</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.004</td>
#       <td>38</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.003</td>
#       <td>39</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.007</td>
#       <td>39</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.003</td>
#       <td>40</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>40</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.003</td>
#       <td>41</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>41</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.004</td>
#       <td>42</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>42</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.003</td>
#       <td>43</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.007</td>
#       <td>43</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.003</td>
#       <td>44</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.003</td>
#       <td>44</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.003</td>
#       <td>45</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.004</td>
#       <td>45</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.003</td>
#       <td>46</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.005</td>
#       <td>46</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.003</td>
#       <td>47</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.003</td>
#       <td>47</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.004</td>
#       <td>48</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.004</td>
#       <td>48</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.003</td>
#       <td>49</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.006</td>
#       <td>49</td>
#       <td>eval</td>
#     <
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='159' class='' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       15.90% [159/1000 00:19&lt;01:40]
#     </div>
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[37], line 3
#       1 run = wandb.init(project="ddpm_clouds", config=config, tags=["big"])
# ----> 3 learn.fit(config.epochs, cbs=[WandbCB("ddpm_clouds"), LogPreds(log_every=10)])
#
# File ~/Apps/course22p2/miniai/learner.py:175, in Learner.fit(self, n_epochs, train, valid, cbs, lr)
#     173 if lr is None: lr = self.lr
#     174 if self.opt_func: self.opt = self.opt_func(self.model.parameters(), lr)
# --> 175 with self.cb_ctx('fit'):
#     176     for self.epoch in self.epochs:
#     177         if train: self.one_epoch(True)
#
# File ~/Apps/course22p2/miniai/learner.py:136, in _CbCtxInner.__exit__(self, exc_type, exc_val, traceback)
#     134 chk_exc = globals()[f'Cancel{self.nm.title()}Exception']
#     135 try:
# --> 136     if not exc_type: self.outer.callback(f'after_{self.nm}')
#     137     return exc_type==chk_exc
#     138 except chk_exc: pass
#
# File ~/Apps/course22p2/miniai/learner.py:186, in Learner.callback(self, method_nm)
# --> 186 def callback(self, method_nm): run_cbs(self.cbs, method_nm, self)
#
# File ~/Apps/course22p2/miniai/learner.py:50, in run_cbs(cbs, method_nm, learn)
#      48 for cb in sorted(cbs, key=attrgetter('order')):
#      49     method = getattr(cb, method_nm, None)
# ---> 50     if method is not None: method(learn)
#
# Cell In[28], line 26, in WandbCB.after_fit(self, learn)
#      24 model_name = f"{wandb.run.id}_{self.model_name}"
#      25 at = wandb.Artifact(model_name, type="model")
# ---> 26 torch.save(learn.model.state_dict(), f"models/{self.model_name}.pth")
#      27 at.add_file(f"models/{self.model_name}.pth")
#      28 wandb.log_artifact(at)
#
# File ~/mambaforge/envs/pt/lib/python3.10/site-packages/torch/serialization.py:422, in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     419 _check_dill_version(pickle_module)
#     421 if _use_new_zipfile_serialization:
# --> 422     with _open_zipfile_writer(f) as opened_zipfile:
#     423         _save(obj, opened_zipfile, pickle_module, pickle_protocol)
#     424         return
#
# File ~/mambaforge/envs/pt/lib/python3.10/site-packages/torch/serialization.py:309, in _open_zipfile_writer(name_or_buffer)
#     307 else:
#     308     container = _open_zipfile_writer_buffer
# --> 309 return container(name_or_buffer)
#
# File ~/mambaforge/envs/pt/lib/python3.10/site-packages/torch/serialization.py:287, in _open_zipfile_writer_file.__init__(self, name)
#     286 def __init__(self, name) -> None:
# --> 287     super(_open_zipfile_writer_file, self).__init__(torch._C.PyTorchFileWriter(str(name)))
#
# RuntimeError: Parent directory models does not exist.

# %%
wandb.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>lr</td><td>▁▁▂▂▃▄▅▆▇▇███████▇▇▇▇▆▆▅▅▅▄▄▃▃▃▂▂▂▂▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▁▁▁▂▃▁▂▁▁▃▄▁▁▁▁▃▁▁▁▁▁▁▂▁▂▁▇▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>99</td></tr><tr><td>loss</td><td>0.007</td></tr><tr><td>lr</td><td>0.0</td></tr><tr><td>train</td><td>eval</td></tr><tr><td>train_loss</td><td>0.00011</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">brilliant-noodles-69</strong> at: <a href="https://wandb.ai/capecape/ddpm_clouds/runs/zdggd0q5" target="_blank">https://wandb.ai/capecape/ddpm_clouds/runs/zdggd0q5</a><br/>Synced 5 W&B file(s), 60 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230127_012404-zdggd0q5/logs</code>
